# %%
import qutipnacs as qtnacs
import qutip as qt
import numpy as np

# %%
qtnacs.set_n(2)

# %%
#coords = [[0,0], [0,1], [0,2], [0,3]]
#interaction_coeff = [[6, 3],[8]]
#atom_types = [0,0,1,1]
#powers = -6

coords = [[0,0], [0,1]]
interaction_coeff = 0
atom_types = [0,0]
powers = -6

omega = 1 * 2 * np.pi
det = 0

H = qtnacs.DrivenRyd(omega, det, coords, interaction_coeff, atom_types, powers)

# %%
res = qtnacs.time_indep_unitary(H, [0,0], 3, 100, [[1,1]], True)
